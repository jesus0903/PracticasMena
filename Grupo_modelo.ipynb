# %% [markdown]
# <a href="https://colab.research.google.com/github/jesus0903/PracticasMena/blob/main/Grupo_modelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clonar el repositorio oficial de YOLOv5
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# 2. Instalar las dependencias necesarias
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17483, done.
# remote: Total 17483 (delta 0), reused 0 (delta 0), pack-reused 17483 (from 1)
# Receiving objects: 100% (17483/17483), 16.55 MiB | 17.45 MiB/s, done.
# Resolving deltas: 100% (11995/11995), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.6 MB/s eta 0:00:00
# ...

# %%
# !unzip -q /content/data.zip -d /content/

# %%
# !ls /content/data/images/train | head -n 5
# !ls /content/data/labels/train | head -n 5
# Out:
# 000022902-005_001_700x700.jpg
# 00110010394830____1__640x640.jpg
# 001-1.jpg
# 00789111207462L.jpg
# 00978849928065l.jpg
# 000022902-005_001_700x700.txt
# 00110010394830____1__640x640.txt
# 001-1.txt
# 00789111207462L.txt
# 00978849928065l.txt

# %%
# %%writefile data.yaml
# train: /content/data/images/train
# val: /content/data/images/val
#
# nc: 3
# names: ['Dinero', 'Pistola', 'Cuchillo']
# Out:
# Writing data.yaml

# %%
# !cat data.yaml
# Out:
# train: /content/data/images/train
# val: /content/data/images/val
#
# nc: 3
# names: ['Dinero', 'Pistola', 'Cuchillo']

# %%
# !python train.py \
  --img 896 \
  --batch 16 \
  --epochs 100 \
  --data data.yaml \
  --weights yolov5x.pt \
  --name entrenamiento_grupo_modelo
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#       86/99      41.8G    0.01958    0.01847   0.000269         82        896:  34% 61/180 [00:21<00:41,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       86/99      41.8G    0.01963    0.01841  0.0002666         61        896:  34% 62/180 [00:22<00:42,  2.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       86/99      41.8G    0.01959    0.01836  0.0002634         61        896:  35% 63/180 [00:22<00:41,  2.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
from IPython.display import Image
Image(filename='/content/yolov5/runs/train/entrenamiento_grupo_modelo/results.png')

# %%
Image(filename='/content/yolov5/runs/train/entrenamiento_grupo_modelo/confusion_matrix.png')
